# %% [markdown]
# <a href="https://colab.research.google.com/github/davirezende1998/Builder/blob/main/dcc099.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EXEMPLO DE ARQUIVO NOTEBOOK: CÉLULA DE TEXTO

# %%
'''CÉLULA DE CÓDIGO'''

print("EXEMPLO DE CÉLULA DE CÓDIGO");
print("OLÁ MUNDO!");
# Out:
# EXEMPLO DE CÉLULA DE CÓDIGO
# OLÁ MUNDO!

# %% [markdown]
# ![1_8N7xbq6ahVvWkEq_S5EhMA.jpeg](data:image/jpeg;base64,...)
